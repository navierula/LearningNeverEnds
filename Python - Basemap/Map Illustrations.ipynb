# %% [markdown]
# # Map Illustrations

# %% [markdown]
# In this notebook, I'll be exploring various features in the Basemap library in Python and using matplotlib to display my visuals!

# %% [markdown]
# I currently have a MAC OS X El Capitan, Version 10.11.5 and simply followed type these magic lines into my terminal to install the package.
#
# * brew install gdal
# * conda install basemap

# %% [markdown]
# If you still have issues, I'd suggest referring to the basemap documentation: http://basemaptutorial.readthedocs.io/en/latest/index.html
#
# Since this is my first interaction with the library as well, I am also using it to assist me in learning the basics and divising this notebook.

# %%
# display contents in notebook
# %matplotlib inline 
# import basemap library and matplot library
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
# set size of map
plt.figure(figsize=(12,6))
map = Basemap()
# draw a flat, basic map of the world
map.drawcoastlines()
plt.show()
